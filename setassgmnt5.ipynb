# %%
#printout all color in a set
color_a=set(input("enter the color separated by comma :").split(","))
color_b=set(input("enter the color separated by comma :").split(","))
difference_set=color_a-color_b
print("difference_set :",difference_set)
# Out:
# enter the color separated by comma : yellow,red,green
# enter the color separated by comma : yellow,green
# difference_set : {'red'}

# %%
#union
a=set(input("enter the color separted by comma").split(","))
b=set(input("enter the color separted by comma").split(","))
colors=a|b
print("colors are :",colors)
# Out:
# enter the color separted by comma yellow,red,green
# enter the color separted by comma blue,pink,red
# colors are : {'yellow', 'red', 'blue', 'green', 'pink'}
