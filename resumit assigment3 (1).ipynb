# %%
#string swapping
s1=input("enter the string :")
s2=input("enter the string :")
new_s1=s2[0]+s1[1:]
new_s2=s1[0]+s2[1:]
print(new_s1+ "" + new_s2)
# Out:
# enter the string : hello
# enter the string : world
# wellohorld

# %%
#string swapping
s1=input("enter the string :")
s2=input("enter the string :")
new_s1=s2[0]+s1[1:]
new_s2=s1[0]+s2[1:]
print(new_s1+ " " + new_s2)
# Out:
# enter the string : hello
# enter the string : world
# wello horld
