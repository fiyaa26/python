# %%
#3rd
numbers=input("enter the numbers separated by comma  ; ")
numbers=tuple(map(int,numbers.split(",")))              
print("3rd elements :",numbers[2])
print("3rd elemnt from last :",numbers[-3])
# Out:
# enter the numbers separated by comma  ;  10,20,30,40,50,60
# 3rd elements : 30
# 3rd elemnt from last : 40

# %%
#commas
numbers = input("Enter numbers separated by commas: ")
num_tuple = tuple(map(float, numbers.split(",")))
average = sum(num_tuple) / len(num_tuple)
print("Tuple:", num_tuple)
print("Average:", average)
# Out:
# Enter numbers separated by commas:  10,20,30,40,50
# Tuple: (10.0, 20.0, 30.0, 40.0, 50.0)
# Average: 30.0
