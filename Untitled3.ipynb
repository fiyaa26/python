# %%
#list
fruits=["apple","banana","organe"]
print(fruits)
# Out:
# ['apple', 'banana', 'organe']

# %%
students=["fiya",21,True]
print(students)
# Out:
# ['fiya', 21, True]

# %%
fruits=["apple","banana","organe"]
print(fruits[2])
# Out:
# organe

# %%
fruits=["apple","banana","organe"]
print(fruits[-2])
# Out:
# banana

# %%
fruits=["apple","banana","organe"]
fruits[2]="mango"
print(fruits)
# Out:
# ['apple', 'banana', 'mango']

# %%
fruits=["apple","banana","organe"]
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'organe', 'orange']

# %%
fruits=["apple","banana","organe"]
fruits.insert(1,"mango")
print(fruits)
# Out:
# ['apple', 'mango', 'banana', 'organe', 'orange']

# %%
fruits=["apple","banana","organe"]
fruits.remove("orange")
print(fruits)
# Out:
# ['apple', 'mango', 'banana', 'organe']

# %%
fruits=["apple","banana","organe"]
fruits.pop(1)
print(fruits)
# Out:
# ['apple', 'organe']

# %%
number=[10,20,30,40,50,]
print(number[0:4])
# Out:
# [10, 20, 30, 40]

# %%
#tuple
number=(1,3,5,2)
print(number)
# Out:
# (1, 3, 5, 2)

# %%
number=(1,3,5,2)
print(number[1])
print(number[3])
# Out:
# 3
# 2

# %%
number=(1,3,5,2)
print(number[-1])
print(number[-3])
# Out:
# 2
# 3

# %%
numbers=(1,2,3,4)
number[0]=10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 numbers=(1,2,3,4)
# ----> 2 number[0]=10
#
# TypeError: 'tuple' object does not support item assignment

# %%
numbers=(10,20,30,40,50,20,20)
print(numbers.count(20))
# Out:
# 3

# %%
numbers=(10,20,30,40,50,20,20)
print(numbers.index(10))
# Out:
# 0

# %%
#range
number=tuple(range(1,10))
print(number)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9)
