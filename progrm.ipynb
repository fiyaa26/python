# %%
name=input("enter your name:")
print("hello",name)
print(type(name))
# Out:
# enter your name:fiya
# hello fiya
# <class 'str'>

# %%
#read age
age=input("enter your age:")
print("hello",age)
print(type(age))
# Out:
# enter your age:21
# hello 21
# <class 'str'>

# %%
#sum
a=int(input("enter your no"))
b=int(input("enter your no"))
sum=a+b
print("sum=",sum)
# Out:
# enter your no1
# enter your no2
# sum= 3

# %%
#sqrt
import math
number=int(input("enter the number"))
result=math.sqrt(number)
print(round(result,2))
# Out:
# enter the number44
# 6.63
