# %%
#string swapping
s1=input("enter the string")
s2=input("enter the string")
new_s1=s2[0]+s[1:]
new_s2=s1[0]+s[1:]
print(new_s1+ "" + new_s2)
# Out:
# enter the string hello
# enter the string world
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 s1=input("enter the string")
#       3 s2=input("enter the string")
# ----> 4 new_s1=s2[0]+s[1:]
#       5 new_s2=s1[0]+s[1:]
#       6 print(new_s1+ "" + new_s2)
#
# NameError: name 's' is not defined
