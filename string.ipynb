# %%
name=('fiya')
print(name)
# Out:
# fiya

# %%
name=('fiya')
print(name[0])
# Out:
# f

# %%
name=('fiya')
print(name[-1,1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 name=('fiya')
# ----> 2 print(name[-1,1])
#
# TypeError: string indices must be integers, not 'tuple'

# %%
name=('fiya')
print(name[0:3])
# Out:
# fiy

# %%
name=('fiya firos')
print(name[0:10:2])
# Out:
# fy io

# %%
name=('fiya firos')
print(name[0:-1])
# Out:
# fiya firo

# %%
name=('fiya firos')
print(name[1:-1])
# Out:
# iya firo

# %%
a="hello"
b="world"
print(a+" " + b)
# Out:
# hello world

# %%
a="hello"
b=(a[0:3] + "world")
print(b)
# Out:
# helworld

# %%
a="hello"
b=(a[0:3] + " " + "world")
print(b)
# Out:
# hel world

# %%
a="hello"
print(len(a))
# Out:
# 5

# %%
a="hello"
print(a.upper())
# Out:
# HELLO

# %%
name="fiya"
r=name[::-1]
print(r)
# Out:
# ayif
