# %%
#python program to celsius to fahrenheit
celsius=float(input("enter the temperture in celsius"))
fahrenheit=(celsius*9/5)+32
print("temperture in fahrenheit =",fahrenheit)
# Out:
# enter the temperture in celsius 12
# temperture in fahrenheit = 53.6

# %%
kilometer=int(input("enter the value :"))
miles=(kilometer*0.621371)
print("km into miles = ",miles)
# Out:
# enter the value : 22
# km into miles =  13.670162
