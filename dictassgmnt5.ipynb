# %%
student={}
name1=input("enter the name :")
roll1=int(input("enter the roll_no :"))

name2=input("enter the name :")
roll2=int(input("enter the roll_no :"))

name3=input("enter the name :")
roll3=int(input("enter the roll_no :"))

name4=input("enter the name :")
roll4=int(input("enter the roll_no :"))

name5=input("enter the name :")
roll5=int(input("enter the roll_no :"))
student={
roll1:name1,
roll2:name2,
roll3:name3,
roll4:name4,
roll5:name5,}
print("ascending order :")
print(dict(sorted(student.items())))

print("descending order :")name4=input("enter the name :")
roll4=int(inputroll4:name4,
roll5:name5,}("enter the roll_no :"))

name5=input("enter the name :")
roll5=int(input("enter the roll_no :"))
print(dict(sorted(student.items(),reverse=True)))
# Out:
# enter the name : fiya
# enter the roll_no : 21
# enter the name : siya24
# enter the roll_no : 24
# enter the name : diya
# enter the roll_no : 19
# enter the name : niya
# enter the roll_no : 27
# enter the name : hiya
# enter the roll_no : 23
# ascending order :
# {19: 'diya', 21: 'fiya', 23: 'hiya', 24: 'siya24', 27: 'niya'}
# descending order :
# {27: 'niya', 24: 'siya24', 23: 'hiya', 21: 'fiya', 19: 'diya'}

# %%
dict={}
name1=input("enter the name :")
roll1=int(input("enter the roll_no :"))

name2=input("enter the name :")
roll2=int(input("enter the roll_no :"))

name3=input("enter the name :")
roll3=int(input("enter the roll_no :"))
dict1={
    roll1:name1,
roll2:name2,
roll3:name3
}
dict2={}
name4=input("enter the name :")
roll4=int(input("enter the roll_no :"))

name5=input("enter the name :")
roll5=int(input("enter the roll_no :"))

dict2={
    roll4:name4,
roll5:name5}

dict1.update(dict2)
print("merged dict :",dict1)
# Out:
# enter the name : fiya
# enter the roll_no : 21
# enter the name : siya
# enter the roll_no : 34
# enter the name : haya
# enter the roll_no : 31
# enter the name : kiya
# enter the roll_no : 9
# enter the name : giya
# enter the roll_no : 23
# merged dict : {21: 'fiya', 34: 'siya', 31: 'haya', 9: 'kiya', 23: 'giya'}
