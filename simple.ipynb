# %%
print("python programming")
# Out:
# python programming

# %%
print("karapoyil kuniyil house\npo pullokkara\nkannur\n670672")
# Out:
# karapoyil kuniyil house
# po pullokkara
# kannur
# 670672

# %%
print(hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(hello)
#
# NameError: name 'hello' is not defined

# %%
PRINT("hai")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 PRINT("hai")
#
# NameError: name 'PRINT' is not defined

# %%
print(5/2)
# Out:
# 2.5

# %%
print(5/2,numerical)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(5/2,numerical)
#
# NameError: name 'numerical' is not defined

# %%
print(5//2)
# Out:
# 2

# %%
print(2**3)
# Out:
# 8

# %%
print("KSB'S STUDENTS")
# Out:
# KSB'S STUDENTS

# %%
print("("KSB STUDENTS")")
# Out:
#   Cell In[15], line 1
#     print("("KSB STUDENTS")")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('"KSB" STUDENTS')
# Out:
# "KSB" STUDENTS

# %%
print('"KSB\s"students')
# Out:
# "KSB\s"students
