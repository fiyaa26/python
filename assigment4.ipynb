# %%
#the color separate by comma
a=(input("enter the color separate by comma : "))
colors=a.split(",")
print("first_color : ",colors[0])
print("second_color :",colors[-1])
# Out:
# enter the color separate by comma :  red,blue,green
# first_color :  red
# second_color : green

# %%
#extension
filename=input("enter the  filename ")
extension=filename.split(".")[-1]
print("extension:",extension)
# Out:
# enter the  filename  photo.jpg
# extension: jpg

# %%
numbers=input("enter comma-separated numbers :")
num_list=numbers.split(",")
num_list=[int(x) for x in num_list]
print("list :",num_list)
print("sum:",sum(num_list))
# Out:
# enter comma-separated numbers : 10,20,30,40,50
# list : [10, 20, 30, 40, 50]
# sum: 150
